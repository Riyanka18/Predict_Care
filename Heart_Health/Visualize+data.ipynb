# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
df=pd.read_csv("C:/Users/User\Desktop\PredictCare\Heart_Health\cleveland.csv")

# %%
df.head()
# Out:
#    age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  slope  \
# 0   63    1   3       145   233    1        0      150      0      2.3      0
# 1   37    1   2       130   250    0        1      187      0      3.5      0
# 2   41    0   1       130   204    0        0      172      0      1.4      2
# 3   56    1   1       120   236    0        1      178      0      0.8      2
# 4   57    0   0       120   354    0        1      163      1      0.6      2
#
#    ca  thal  target
# 0   0     1       1
# 1   0     2       1
# 2   0     2       1
# 3   0     2       1
# 4   0     2       1

# %%
df.shape
# Out:
# (303, 14)

# %%
df.isnull().sum()
# Out:
# age         0
# sex         0
# cp          0
# trestbps    0
# chol        0
# fbs         0
# restecg     0
# thalach     0
# exang       0
# oldpeak     0
# slope       0
# ca          0
# thal        0
# target      0
# dtype: int64

# %%
df.isnull().values.any()
# Out:
# False

# %%
df.describe()
# Out:
#               age         sex          cp    trestbps        chol         fbs  \
# count  303.000000  303.000000  303.000000  303.000000  303.000000  303.000000
# mean    54.366337    0.683168    0.966997  131.623762  246.264026    0.148515
# std      9.082101    0.466011    1.032052   17.538143   51.830751    0.356198
# min     29.000000    0.000000    0.000000   94.000000  126.000000    0.000000
# 25%     47.500000    0.000000    0.000000  120.000000  211.000000    0.000000
# 50%     55.000000    1.000000    1.000000  130.000000  240.000000    0.000000
# 75%     61.000000    1.000000    2.000000  140.000000  274.500000    0.000000
# max     77.000000    1.000000    3.000000  200.000000  564.000000    1.000000
#
#           restecg     thalach       exang     oldpeak       slope          ca  \
# count  303.000000  303.000000  303.000000  303.000000  303.000000  303.000000
# mean     0.528053  149.646865    0.326733    1.039604    1.399340    0.729373
# std      0.525860   22.905161    0.469794    1.161075    0.616226    1.022606
# min      0.000000   71.000000    0.000000    0.000000    0.000000    0.000000
# 25%      0.000000  133.500000    0.000000    0.000000    1.000000    0.000000
# 50%      1.000000  153.000000    0.000000    0.800000    1.000000    0.000000
# 75%      1.000000  166.000000    1.000000    1.600000    2.000000    1.000000
# max      2.000000  202.000000    1.000000    6.200000    2.000000    4.000000
#
#              thal      target
# count  303.000000  303.000000
# mean     2.313531    0.544554
# std      0.612277    0.498835
# min      0.000000    0.000000
# 25%      2.000000    0.000000
# 50%      2.000000    1.000000
# 75%      3.000000    1.000000
# max      3.000000    1.000000

# %%
df['target'].value_counts()
# Out:
# 1    165
# 0    138
# Name: target, dtype: int64

# %%
sns.countplot(df['target'])

# %%
df['years']=(df['age']/365).round(0)
df['years']=pd.to_numeric(df['years'],downcast='integer')

# %%
df.head(3)
# Out:
#    age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  slope  \
# 0   63    1   3       145   233    1        0      150      0      2.3      0
# 1   37    1   2       130   250    0        1      187      0      3.5      0
# 2   41    0   1       130   204    0        0      172      0      1.4      2
#
#    ca  thal  target  years
# 0   0     1       1      0
# 1   0     2       1      0
# 2   0     2       1      0

# %%
#visualizing the number of people with and without heart disease at that specific age
sns.countplot(x='years',hue='cardio',data=df,palette='colorblind',
              edgecolor=sns.color_palette('dark',n_colors=1))
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-13-359a7c3210fb> in <module>()
#       1 #visualizing the number of people with and without heart disease at that specific age
#       2 sns.countplot(x='years',hue='cardio',data=df,palette='colorblind',
# ----> 3               edgecolor=sns.color_palette('dark',n_colors=1))
#
# ~\Anaconda3\lib\site-packages\seaborn\categorical.py in countplot(x, y, hue, data, order, hue_order, orient, color, palette, saturation, dodge, ax, **kwargs)
#    3338                           estimator, ci, n_boot, units,
#    3339                           orient, color, palette, saturation,
# -> 3340                           errcolor, errwidth, capsize, dodge)
#    3341
#    3342     plotter.value_label = "count"
#
# ~\Anaconda3\lib\site-packages\seaborn\categorical.py in __init__(self, x, y, hue, data, order, hue_order, estimator, ci, n_boot, units, orient, color, palette, saturation, errcolor, errwidth, capsize, dodge)
#    1584         """Initialize the plotter."""
#    1585         self.establish_variables(x, y, hue, data, orient,
# -> 1586                                  order, hue_order, units)
#    1587         self.establish_colors(color, palette, saturation)
#    1588         self.estimate_statistic(estimator, ci, n_boot)
#
# ~\Anaconda3\lib\site-packages\seaborn\categorical.py in establish_variables(self, x, y, hue, data, orient, order, hue_order, units)
#     149                 if isinstance(input, string_types):
#     150                     err = "Could not interpret input '{}'".format(input)
# --> 151                     raise ValueError(err)
#     152
#     153             # Figure out the plotting orientation
#
# ValueError: Could not interpret input 'cardio'

# %%
#Correlation
df.iloc[:,1:12].corr()
# Out:
#                sex        cp  trestbps      chol       fbs   restecg  \
# sex       1.000000 -0.049353 -0.056769 -0.197912  0.045032 -0.058196
# cp       -0.049353  1.000000  0.047608 -0.076904  0.094444  0.044421
# trestbps -0.056769  0.047608  1.000000  0.123174  0.177531 -0.114103
# chol     -0.197912 -0.076904  0.123174  1.000000  0.013294 -0.151040
# fbs       0.045032  0.094444  0.177531  0.013294  1.000000 -0.084189
# restecg  -0.058196  0.044421 -0.114103 -0.151040 -0.084189  1.000000
# thalach  -0.044020  0.295762 -0.046698 -0.009940 -0.008567  0.044123
# exang     0.141664 -0.394280  0.067616  0.067023  0.025665 -0.070733
# oldpeak   0.096093 -0.149230  0.193216  0.053952  0.005747 -0.058770
# slope    -0.030711  0.119717 -0.121475 -0.004038 -0.059894  0.093045
# ca        0.118261 -0.181053  0.101389  0.070511  0.137979 -0.072042
#
#            thalach     exang   oldpeak     slope        ca
# sex      -0.044020  0.141664  0.096093 -0.030711  0.118261
# cp        0.295762 -0.394280 -0.149230  0.119717 -0.181053
# trestbps -0.046698  0.067616  0.193216 -0.121475  0.101389
# chol     -0.009940  0.067023  0.053952 -0.004038  0.070511
# fbs      -0.008567  0.025665  0.005747 -0.059894  0.137979
# restecg   0.044123 -0.070733 -0.058770  0.093045 -0.072042
# thalach   1.000000 -0.378812 -0.344187  0.386784 -0.213177
# exang    -0.378812  1.000000  0.288223 -0.257748  0.115739
# oldpeak  -0.344187  0.288223  1.000000 -0.577537  0.222682
# slope     0.386784 -0.257748 -0.577537  1.000000 -0.080155
# ca       -0.213177  0.115739  0.222682 -0.080155  1.000000

# %%
#plot the correlation
plt.figure(figsize=(7,7))
sns.heatmap(df.iloc[:,0:13].corr(),annot=True)

# %%
#age and years become concurrent and have same correlation so we need to remove age co0lumn
#also remove the id column
=df.drop('years',axis=1)
df=df.drop('id',axis=1)

# %%
df.head()
# Out:
#      age  gender  height  weight  ap_hi  ap_lo  cholesterol  gluc  smoke  \
# 0  18393       2     168    62.0    110     80            1     1      0
# 1  20228       1     156    85.0    140     90            3     1      0
# 2  18857       1     165    64.0    130     70            3     1      0
# 3  17623       2     169    82.0    150    100            1     1      0
# 4  17474       1     156    56.0    100     60            1     1      0
#
#    alco  active  cardio
# 0     0       1       0
# 1     0       1       1
# 2     0       0       1
# 3     0       1       1
# 4     0       0       0
